# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\fenny\OneDrive\Desktop\heart.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.shape
print("The number of rows are",data.shape[0])
print("The number of rows are",data.shape[1])
# Out:
# The number of rows are 1025
# The number of rows are 14

# %%
data=data.rename(columns={"cp":"chest_pain","trestbps":"resting_bp","fbs":"fasting_blood_sugar"})

# %%
data
# Out:
#       age  sex  chest_pain  resting_bp  chol  fasting_blood_sugar  restecg  \
# 0      52    1           0         125   212                    0        1
# 1      53    1           0         140   203                    1        0
# 2      70    1           0         145   174                    0        1
# 3      61    1           0         148   203                    0        1
# 4      62    0           0         138   294                    1        1
# ...   ...  ...         ...         ...   ...                  ...      ...
# 1020   59    1           1         140   221                    0        1
# 1021   60    1           0         125   258                    0        0
# 1022   47    1           0         110   275                    0        0
# 1023   50    0           0         110   254                    0        0
# 1024   54    1           0         120   188                    0        1
#
#       thalach  exang  oldpeak  slope  ca  thal  target
# ...

# %%
duplicates=data[data.duplicated()]
data=data.drop_duplicates()
print(data)
# Out:
#      age  sex  chest_pain  resting_bp  chol  fasting_blood_sugar  restecg  \
# 0     52    1           0         125   212                    0        1
# 1     53    1           0         140   203                    1        0
# 2     70    1           0         145   174                    0        1
# 3     61    1           0         148   203                    0        1
# 4     62    0           0         138   294                    1        1
# ..   ...  ...         ...         ...   ...                  ...      ...
# 723   68    0           2         120   211                    0        0
# 733   44    0           2         108   141                    0        1
# 739   52    1           0         128   255                    0        1
# 843   59    1           3         160   273                    0        0
# 878   54    1           0         120   188                    0        1
#
#      thalach  exang  oldpeak  slope  ca  thal  target
# ...

# %%
data
# Out:
#      age  sex  chest_pain  resting_bp  chol  fasting_blood_sugar  restecg  \
# 0     52    1           0         125   212                    0        1
# 1     53    1           0         140   203                    1        0
# 2     70    1           0         145   174                    0        1
# 3     61    1           0         148   203                    0        1
# 4     62    0           0         138   294                    1        1
# ..   ...  ...         ...         ...   ...                  ...      ...
# 723   68    0           2         120   211                    0        0
# 733   44    0           2         108   141                    0        1
# 739   52    1           0         128   255                    0        1
# 843   59    1           3         160   273                    0        0
# 878   54    1           0         120   188                    0        1
#
#      thalach  exang  oldpeak  slope  ca  thal  target
# ...

# %%
data.describe()
# Out:
#              age         sex  chest_pain  resting_bp        chol  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000
# std      9.04797    0.466426    1.032044   17.563394   51.753489
# min     29.00000    0.000000    0.000000   94.000000  126.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000
# max     77.00000    1.000000    3.000000  200.000000  564.000000
#
#        fasting_blood_sugar     restecg     thalach       exang     oldpeak  \
# count           302.000000  302.000000  302.000000  302.000000  302.000000
# mean              0.149007    0.526490  149.569536    0.327815    1.043046
# std               0.356686    0.526027   22.903527    0.470196    1.161452
# min               0.000000    0.000000   71.000000    0.000000    0.000000
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
#find male and female patients in the dataset
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
male_count=len(data[data['sex']==1])
female_count=len(data[data['sex']==0])
print("Number of males in the dataset are",male_count,"and number of females in the dataset are",female_count)
# Out:
# Number of males in the dataset are 206 and number of females in the dataset are 96

# %%
#How many people have heart diseases how many don't have heart disease
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
#which gender has the most heart disease
female_hd_count=len(data[(data['sex']==0)&(data['target']==1)])
print(female_hd_count)
# Out:
# 72

# %%
male_hd_count=len(data[(data['sex']==1)&(data['target']==1)])
print(male_hd_count)
# Out:
# 92

# %%
#Check Age Distribution In The Dataset
sns.distplot(data['age'],bins=20)
plt.title("Age distribution in the dataset")
plt.show()
# Out:
# C:\Users\fenny\AppData\Local\Temp\ipykernel_30800\1730991356.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=20)
# C:\Users\fenny\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Check Chest Pain Type
data['chest_pain'].value_counts()
# Out:
# chest_pain
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
summary = data.groupby('chest_pain')['age'].describe()
print(summary)
# Out:
#             count       mean        std   min    25%   50%   75%   max
# chest_pain
# 0           143.0  55.692308   8.312752  35.0  51.00  57.0  62.0  77.0
# 1            50.0  51.360000   9.512098  29.0  44.25  52.0  57.0  74.0
# 2            86.0  53.697674   9.323051  37.0  47.00  53.0  60.0  76.0
# 3            23.0  55.869565  10.033147  34.0  51.50  59.0  63.5  69.0

# %%
sns.countplot(x="chest_pain",hue="target",data=data)
plt.legend(labels=["No-risk","Risk"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.countplot(x="chest_pain",hue="target",data=data)
#       2 plt.legend(labels=["No-risk","Risk"])
#
# File ~\anaconda4\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda4\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda4\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
fbs_target=len(data[(data['fasting_blood_sugar']==1)&(data['target']==1)])
nfbs_target=len(data[(data['fasting_blood_sugar']==0)&(data['target']==1)])
print(fbs_target)
print(nfbs_target)
# Out:
# 23
# 141

# %%
#Show Fasting Blood Sugar Distribution According To Target Variable
sns.countplot(x="fasting_blood_sugar",hue="target",data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 2
#       1 #Show Fasting Blood Sugar Distribution According To Target Variable
# ----> 2 sns.countplot(x="fasting_blood_sugar",hue="target",data=data)
#       3 plt.show()
#
# File ~\anaconda4\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda4\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#Check Resting Blood Pressure Distribution
data.columns
# Out:
# Index(['age', 'sex', 'chest_pain', 'resting_bp', 'chol', 'fasting_blood_sugar',
#        'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal',
#        'target'],
#       dtype='object')

# %%
data.hist('resting_bp')
# Out:
# array([[<Axes: title={'center': 'resting_bp'}>]], dtype=object)

# %%
#Compare Resting Blood Pressure As Per Sex Column
g=sns.FacetGrid(data,hue="sex",aspect=4)
g.map(sns.kdeplot,'resting_bp',shade=True)
plt.legend(labels=['Male','Female'])
# Out:
# C:\Users\fenny\anaconda4\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\fenny\anaconda4\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\fenny\anaconda4\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
#Show Distribution of Serum cholesterol
data['chol'].hist()
# Out:
# <Axes: >
